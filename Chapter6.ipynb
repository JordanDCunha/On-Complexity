# %% [markdown]
# <a href="https://colab.research.google.com/github/JordanDCunha/On-Complexity/blob/main/Chapter6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 5.1 Introduction — Small World Networks
#
# - Many real-world networks (especially social networks) exhibit the **small world property**.
# - The **small world property** means:
#   - The average distance between nodes is small
#   - Distance is measured as the number of edges in the shortest path
#
# - This chapter explores **Stanley Milgram’s Small World Experiment**:
#   - The first real-world demonstration of the small world property
#   - Showed surprisingly short paths between people in social networks
#
# - The chapter introduces **Watts–Strogatz graphs**:
#   - A network model designed to explain small world behavior
#   - Balances randomness and structure
#
# - We will:
#   - Replicate the Watts–Strogatz experiment
#   - Explain what the model demonstrates about real networks
#
# - Two new graph algorithms are introduced:
#   - **Breadth-First Search (BFS)** — for exploring graphs level by level
#   - **Dijkstra’s Algorithm** — for finding shortest paths in weighted graphs
#
# - All code for this chapter is located in:
#   - `chap05.ipynb` (book repository)
#
# - Additional guidance for working with the code is provided in:
#   - Section 1.4

# %% [markdown]
# ### 5.2 Stanley Milgram and the Small World Experiment
#
# - **Stanley Milgram** was an American social psychologist known for:
#   - The **Milgram Obedience Experiment**
#   - The **Small World Experiment**
#
# - The **Small World Experiment** studied the structure of social networks.
#
# - Experiment setup:
#   - Milgram mailed packages to randomly chosen people in **Wichita, Kansas**
#   - Each package contained a letter addressed to a **target person** in **Sharon, Massachusetts**
#   - The target was identified only by **name and occupation**
#
# - Instructions to participants:
#   - Mail the letter **directly** only if they personally knew the target
#   - Otherwise, forward it to a **friend or relative** more likely to know the target
#   - Include the same instructions with each forwarding
#
# - Results:
#   - Many letters were never delivered
#   - For delivered letters, the **average path length** was about **6**
#   - Path length = number of times the letter was forwarded
#
# - This led to the idea of:
#   - **“Six degrees of separation”**
#   - The average social distance between any two people is small
#
# - Why this result was surprising:
#   - Social networks are generally **localized**
#   - People tend to live near their friends
#   - Local connections usually lead to **longer path lengths**
#
# - Example reasoning:
#   - Average friend distance ≈ 50 miles
#   - Wichita → Boston ≈ 1600 miles
#   - Expected hops ≈ 32
#   - Actual average hops ≈ **6**
#
# - Conclusion:
#   - Social networks are much more interconnected than expected
#   - Long-distance connections dramatically shorten path lengths

# %% [markdown]
# ### 5.3 Watts and Strogatz: Small-World Networks
#
# - In **1998**, **Duncan Watts** and **Steven Strogatz** published:
#   - *“Collective dynamics of ‘small-world’ networks”* in **Nature**
#   - A proposed explanation for the **small world phenomenon**
#
# - They compared two well-known graph types:
#   - **Random graphs**: nodes are connected at random
#   - **Regular graphs**: every node has the same number of neighbors
#
# - They analyzed two key properties of graphs:
#
# - **Clustering**:
#   - Measures the **“cliquishness”** of a graph
#   - A **clique** is a subset of nodes where every node is connected to every other
#   - In social networks: groups where everyone is friends with everyone else
#   - Measured using a **clustering coefficient**
#   - Indicates how likely two neighbors of a node are also connected
#
# - **Path length**:
#   - Measures the **average distance between pairs of nodes**
#   - Corresponds to **degrees of separation** in social networks
#
# - Observations:
#   - **Regular graphs**:
#     - High clustering
#     - Long path lengths
#   - **Random graphs**:
#     - Low clustering
#     - Short path lengths
#
# - Problem:
#   - Real social networks show **high clustering** *and* **short path lengths**
#   - Neither regular nor random graphs alone model this well
#
# - Goal:
#   - Create a **generative model** for social networks
#   - A generative model explains a phenomenon by modeling the process that creates it
#
# - **Watts–Strogatz model process**:
#   - Start with a **regular graph** with:
#     - \( n \) nodes
#     - Each node connected to \( k \) neighbors
#   - Randomly **rewire** a subset of edges
#   - Each edge is rewired with probability \( p \)
#
# - Role of \( p \):
#   - \( p = 0 \): completely regular graph
#   - \( p = 1 \): completely random graph
#   - Small values of \( p \):
#     - High clustering (like regular graphs)
#     - Short path lengths (like random graphs)
#
# - Key result:
#   - Small-world networks emerge with **only a small amount of randomness**
#
# - Plan for the chapter:
#   - Construct a **ring lattice** (regular graph)
#   - Rewire edges using the Watts–Strogatz method
#   - Measure clustering and path length
#   - Analyze results for different values of \( p \)
#   - Explore **Dijkstra’s algorithm** for shortest paths

# %% [markdown]
# ### 5.4 Ring Lattice
#
# - A **regular graph** is a graph where:
#   - Every node has the same number of neighbors
#   - The number of neighbors is called the **degree** of the node
#
# - A **ring lattice** is a type of regular graph used by **Watts and Strogatz**
#   - Nodes are arranged in a **circle**
#   - Each node is connected to its **k nearest neighbors**
#
# - Parameters:
#   - \( n \): number of nodes
#   - \( k \): number of neighbors per node (degree)
#
# - In a ring lattice:
#   - Edges **wrap around** from the highest-numbered node back to node 0
#   - This wrap-around behavior creates the circular structure
#
# - The ring lattice serves as the **starting point** for the Watts–Strogatz small-world model

# %%
def adjacent_edges(nodes, halfk):
    n = len(nodes)
    for i, u in enumerate(nodes):
        for j in range(i + 1, i + halfk + 1):
            v = nodes[j % n]
            yield u, v

# %% [markdown]
# - `adjacent_edges` is a **generator function**
# - Inputs:
#   - `nodes`: list or range of node labels
#   - `halfk`: half of \( k \), the number of neighbors on one side
#
# - For each node:
#   - Connects it to the next `halfk` nodes
#   - Uses the **modulus operator (`%`)** to wrap around the ring
#
# - This ensures:
#   - Circular connectivity
#   - Every node ends up with the same degree

# %%
nodes = range(3)

for edge in adjacent_edges(nodes, 1):
    print(edge)

# %% [markdown]
# - Output edges:
#   - (0, 1)
#   - (1, 2)
#   - (2, 0)
#
# - This confirms:
#   - Edges wrap around from the last node back to the first
#   - The structure forms a closed ring

# %%
def make_ring_lattice(n, k):
    G = nx.Graph()
    nodes = range(n)
    G.add_nodes_from(nodes)
    G.add_edges_from(adjacent_edges(nodes, k // 2))
    return G
r

# %% [markdown]
# - `make_ring_lattice` builds a ring lattice graph using NetworkX
#
# - Steps:
#   - Creates an empty undirected graph
#   - Adds `n` nodes
#   - Adds edges using `adjacent_edges`
#
# - Important detail:
#   - Uses **floor division (`k // 2`)**
#   - This works correctly **only if k is even**
#   - If `k` is odd, the resulting graph has degree `k - 1`
#
# - Handling odd `k` values is left as an exercise later in the chapter

# %%
lattice = make_ring_lattice(10, 4)

# %% [markdown]
# - The resulting graph:
#   - Has 10 nodes
#   - Each node is connected to 4 neighbors
#   - Matches the structure shown in **Figure 5.1**

# %% [markdown]
# ### 5.5 Watts–Strogatz (WS) Graphs
#
# - A **Watts–Strogatz (WS) graph** starts from a **ring lattice**
# - Some edges are then **rewired at random**
# - Rewiring introduces **shortcuts** while preserving local structure
#
# - Parameters:
#   - \( n \): number of nodes
#   - \( k \): number of neighbors per node
#   - \( p \): probability that an edge is rewired
#
# - Behavior:
#   - \( p = 0 \): graph is a regular ring lattice
#   - \( p = 1 \): graph is completely random
#   - Intermediate \( p \): **small-world networks** emerge

# %%
def rewire(G, p):
    nodes = set(G)
    for u, v in G.edges():
        if flip(p):
            choices = nodes - {u} - set(G[u])
            new_v = np.random.choice(list(choices))
            G.remove_edge(u, v)
            G.add_edge(u, new_v)

# %% [markdown]
# - `rewire` modifies an existing graph `G`
# - Each edge is considered **one at a time**
# - With probability `p`, an edge is rewired
#
# - Rewiring rules:
#   - The first node (`u`) stays the same
#   - The second node (`v`) is replaced with `new_v`
#   - **Self-loops are not allowed**
#   - **Multiple edges are not allowed**
#
# - To avoid invalid edges:
#   - Possible choices exclude:
#     - Node `u` itself
#     - Existing neighbors of `u`

# %%
def flip(p):
    return np.random.random() < p

# %% [markdown]
# - `flip(p)` simulates a biased coin flip
# - Uses NumPy’s random number generator
#
# - Behavior:
#   - Returns `True` with probability `p`
#   - Returns `False` with probability `1 - p`
#
# - This determines whether a given edge is rewired

# %% [markdown]
# - `G[u]` returns a dictionary of neighbors of node `u`
#   - Faster than calling `G.neighbors(u)`
#
# - The implementation:
#   - Does **not** rewire edges in the exact order described by Watts & Strogatz
#   - This difference does **not significantly affect results**
#
# - Rewiring process:
#   1. Select an edge `(u, v)`
#   2. Randomly choose a new endpoint `new_v`
#   3. Remove `(u, v)`
#   4. Add `(u, new_v)`

# %% [markdown]
# ### Figure 5.2 Interpretation
#
# - WS graphs shown with:
#   - \( n = 20 \)
#   - \( k = 4 \)
#   - Different values of \( p \)
#
# - Observations:
#   - \( p = 0 \): perfectly regular lattice
#   - \( p = 0.2 \): mostly local structure with some shortcuts
#   - \( p = 1 \): completely random graph
#
# - The most interesting network properties occur at **intermediate values of p**

# %% [markdown]
# **Question:**
# As demonstrated in Figure 5.2, what happens as \( p \) increases?
#
# **Correct Answer:**
# ✅ **D. The graph becomes more random**
#
# - Increasing `p` increases the number of rewired edges
# - This gradually destroys the regular lattice structure
# - The graph transitions from ordered → small-world → random

# %% [markdown]
# **Question:**
# As demonstrated in Figure 5.2, what happens as \( p \) increases?
#
# **Correct Answer:**
# ✅ **D. The graph becomes more random**
#
# - Increasing `p` increases the number of rewired edges
# - This gradually destroys the regular lattice structure
# - The graph transitions from ordered → small-world → random

# %% [markdown]
# ### 5.6 Clustering
#
# - The **clustering coefficient** measures how strongly nodes form **cliques**
# - A **clique** is a set of nodes where **every node is connected to every other node**
#
# - Clustering captures how likely it is that:
#   - Two neighbors of a node are also neighbors of each other
#
# - This is especially important for modeling **social networks**

# %%
def node_clustering(G, u):
    neighbors = G[u]
    k = len(neighbors)
    if k < 2:
        return np.nan

    possible = k * (k-1) / 2
    exist = 0
    for v, w in all_pairs(neighbors):
        if G.has_edge(v, w):
            exist +=1
    return exist / possible

# %% [markdown]
# - Computes the **local clustering coefficient** for node `u`
#
# - Steps:
#   - Get neighbors of `u` using `G[u]`
#   - Let `k` be the number of neighbors
#
# - If `k < 2`:
#   - Clustering coefficient is **undefined**
#   - Return `np.nan` (“Not a Number”)
#
# - Otherwise:
#   - Compute number of **possible edges** among neighbors:
#     \[
#     \frac{k(k-1)}{2}
#     \]
#   - Count how many of those edges **actually exist**
#   - Return the fraction that exist

# %% [markdown]
# - We test the function using a ring lattice
# - In a ring lattice with \( k = 4 \):
#   - Each node has the same local clustering coefficient

# %%
lattice = make_ring_lattice(10, 4)
node_clustering(lattice, 1)

# %% [markdown]
# - In a ring lattice with \( k = 4 \):
# - Each node has a clustering coefficient of **0.5**

# %%
def clustering_coefficient(G):
    cu = [node_clustering(G, node) for node in G]
    return np.nanmean(cu)

# %% [markdown]
# - Computes the **network average clustering coefficient**
#
# - Process:
#   - Compute local clustering for each node
#   - Store results in a list
#   - Use `np.nanmean` to ignore undefined values (`np.nan`)
#
# - Result:
#   - A single value representing overall network clustering

# %%
clustering_coefficient(lattice)

# %% [markdown]
# - Since all nodes have clustering coefficient **0.5**:
# - The network average is also **0.5**
#
# - This value will change for **Watts–Strogatz graphs**
# as edges are rewired

# %% [markdown]
# **Question:**
# If a node has fewer than **2** neighbors, the clustering coefficient is **undefined**,
# so we return `np.nan`, which is a special value that indicates **Not a Number**.

# %% [markdown]
# ### 5.7 Shortest Path Lengths
#
# - The **characteristic path length** \( L \) is:
#   - The **average length of the shortest path**
#   - Computed between **every pair of nodes** in a graph
#
# - This corresponds to:
#   - The average **degrees of separation** in a network
#
# - We use NetworkX’s built-in function:
#   - `shortest_path_length`

# %%
def path_lengths(G):
    length_map = nx.shortest_path_length(G)
    lengths = [length_map[u][v] for u, v in all_pairs(G)]
    return lengths

# %% [markdown]
# - `nx.shortest_path_length(G)` returns a **dictionary of dictionaries**
#   - Outer dictionary maps node `u`
#   - Inner dictionary maps node `v`
#   - Value is the shortest path length from `u` to `v`
#
# - `all_pairs(G)` enumerates all node pairs
#
# - The function returns:
#   - A list of shortest path lengths
#   - One value for each pair of nodes

# %%
def characteristic_path_length(G):
    return np.mean(path_lengths(G))

# %% [markdown]
# - Computes the **average shortest path length** \( L \)
#
# - Steps:
#   - Compute all shortest path lengths
#   - Take the **mean** using NumPy
#
# - This gives a single number describing:
#   - How far apart nodes are, on average

# %%
lattice = make_ring_lattice(3, 2)
characteristic_path_length(lattice)

# %% [markdown]
# - In this graph:
# - All 3 nodes are directly connected
# - Every shortest path has length 1
#
# - Therefore:
# - The characteristic path length is **1**

# %% [markdown]
# ### 5.8 The WS Experiment
#
# - Goal:
#   - Replicate the **Watts–Strogatz (WS) experiment**
#   - Show that WS graphs can have:
#     - **High clustering** (like regular graphs)
#     - **Short path lengths** (like random graphs)
#
# - This behavior occurs for a **range of values of p**
#   - Where p controls the probability of edge rewiring

# %%
def run_one_graph(n, k, p):
    ws = make_ws_graph(n, k, p)
    mpl = characteristic_path_length(ws)
    cc = clustering_coefficient(ws)
    return mpl, cc

# %% [markdown]
# - Inputs:
#   - `n`: number of nodes
#   - `k`: number of neighbors per node
#   - `p`: rewiring probability
#
# - Process:
#   - Generate a WS graph
#   - Compute:
#     - Mean path length (mpl)
#     - Clustering coefficient (cc)
#
# - Output:
#   - A tuple: `(mpl, cc)`

# %%
ps = np.logspace(-4, 0, 9)

# %% [markdown]
# - `np.logspace(-4, 0, 9)`:
#   - Generates 9 values of p
#   - Ranges from \(10^{-4}\) to \(10^{0}\)
#   - Values are evenly spaced on a logarithmic scale
#
# - This allows us to observe:
#   - Gradual transition from regular to random graphs

# %%
def run_experiment(ps, n=1000, k=10, iters=20):
    res = []
    for p in ps:
        t = [run_one_graph(n, k, p) for _ in range(iters)]
        means = np.array(t).mean(axis=0)
        res.append(means)
    return np.array(res)

# %% [markdown]
# - For each value of p:
#   - Generate `iters` WS graphs
#   - Compute `(L, C)` for each graph
#   - Average the results
#
# - `t`:
#   - List of `(L, C)` pairs
#
# - `mean(axis=0)`:
#   - Averages path length and clustering separately
#
# - Output:
#   - NumPy array
#   - One row per p
#   - Columns: `[L, C]`

# %%
L, C = np.transpose(res)

# %% [markdown]
# - Transposing the results:
#   - Separates path length (L)
#   - Separates clustering coefficient (C)
#
# - Now:
#   - `L[i]` corresponds to path length at `p[i]`
#   - `C[i]` corresponds to clustering at `p[i]`

# %%
L /= L[0]
C /= C[0]

# %% [markdown]
# - Dividing by the first element:
#   - Normalizes L and C
#   - Makes values comparable on the same plot
#
# - This allows:
#   - Visualization of **relative change**
#   - Clear comparison between clustering and path length

# %% [markdown]
# - As p increases:
#   - **Path length (L)** drops rapidly
#     - Even a few rewired edges create shortcuts
#   - **Clustering (C)** decreases slowly
#     - Local structure remains intact longer
#
# - Result:
#   - Wide range of p where graphs have:
#     - High clustering
#     - Low path length
#
# - Conclusion:
#   - WS graphs successfully model **small-world networks**

# %% [markdown]
# ## 5.10 Breadth-First Search
#
# - Purpose:
#   - Explain how shortest paths are computed
#   - Introduce **Breadth-First Search (BFS)**
#
# - Background:
#   - Previously used `nx.shortest_path_length`
#   - Now we examine the algorithm behind it
#
# - BFS is foundational for:
#   - Shortest path algorithms
#   - Dijkstra’s algorithm

# %%
def reachable_nodes(G, start):
    seen = set()
    stack = [start]
    while stack:
        node = stack.pop()
        if node not in seen:
            seen.add(node)
            stack.extend(G.neighbors(node))
    return seen

# %% [markdown]
# ### Depth-First Search (DFS)
#
# - The function above performs **Depth-First Search**
# - Uses a **stack (LIFO)** structure
# - Explores one branch fully before backtracking
#
# - Characteristics:
#   - Fast
#   - Does NOT guarantee shortest paths

# %% [markdown]
# ### BFS vs DFS Intuition
#
# - DFS:
#   - Go as deep as possible first
#   - Backtrack later
#
# - BFS:
#   - Explore all neighbors first
#   - Then move to the next level
#
# - BFS is better for:
#   - Finding shortest paths

# %%
node = stack.pop(0)

# %% [markdown]
# ### Why This BFS Is Inefficient
#
# - `pop(0)` removes the first element of a list
# - This operation is **O(n)** in Python
#
# - Worst case:
#   - Stack size ≈ n
#   - BFS becomes **O(n²)** ❌
#
# - We need a better data structure

# %% [markdown]
# ### Solution: Deque (Double-Ended Queue)
#
# - A deque allows:
#   - Fast insertion/removal from both ends
#   - All operations are **O(1)**
#
# - Python provides `deque` in the `collections` module

# %%
from collections import deque

# %%
def reachable_nodes_bfs(G, start):
    seen = set()
    queue = deque([start])
    while queue:
        node = queue.popleft()
        if node not in seen:
            seen.add(node)
            queue.extend(G.neighbors(node))
    return seen

# %% [markdown]
# ### BFS Implementation Explanation
#
# - Changes from DFS:
#   - `stack` → `queue`
#   - `pop()` → `popleft()`
#
# - Behavior:
#   - Explores nodes **level by level**
#   - Guarantees shortest paths
#
# - Time complexity:
#   - **O(n + m)**
#     - n = number of nodes
#     - m = number of edges

# %% [markdown]
# ### BFS vs DFS Summary
#
# - **Breadth-First Search (BFS)**:
#   - Level-by-level exploration
#   - Finds shortest paths
#   - Uses a queue
#
# - **Depth-First Search (DFS)**:
#   - Deep exploration
#   - No shortest-path guarantee
#   - Uses a stack

# %% [markdown]
# ### BFS vs DFS Summary
#
# - **Breadth-First Search (BFS)**:
#   - Level-by-level exploration
#   - Finds shortest paths
#   - Uses a queue
#
# - **Depth-First Search (DFS)**:
#   - Deep exploration
#   - No shortest-path guarantee
#   - Uses a stack

# %% [markdown]
# ### Key Takeaway
#
# - BFS is essential for:
#   - Shortest path problems
#   - Network analysis
#   - Dijkstra’s algorithm
#
# - Efficient BFS requires:
#   - A deque, not a list

# %% [markdown]
# ## 5.11 Dijkstra’s Algorithm
#
# - Dijkstra’s algorithm finds the **shortest path** from a single source node
# - It computes the **minimum distance** from the source to every other node
# - Works on graphs with:
#   - Equal edge weights (simplified version)
#   - Or non-negative edge weights (general version)

# %% [markdown]
# ### Key Idea
#
# - This algorithm solves the **single-source shortest path problem**
# - Similar to **Breadth-First Search (BFS)**
# - Difference:
#   - Uses a **distance dictionary** instead of a `seen` set

# %%
from collections import deque

# %%
def shortest_path_dijkstra(G, source):
    dist = {source: 0}
    queue = deque([source])

    while queue:
        node = queue.popleft()
        new_dist = dist[node] + 1

        neighbors = set(G[node]).difference(dist)
        for n in neighbors:
            dist[n] = new_dist

        queue.extend(neighbors)

    return dist

# %% [markdown]
# ### Data Structures Used
#
# - `dist` (dictionary):
#   - Maps each node → distance from the source
#   - Example: `{source: 0}` initially
#
# - `queue` (deque):
#   - Ensures **BFS order**
#   - Nodes are processed by increasing distance

# %% [markdown]
# ### Algorithm Step-by-Step
#
# 1. Initialize:
#    - Distance to source = 0
#    - Add source to the queue
#
# 2. While the queue is not empty:
#    - Remove the next node
#    - Compute distance to its neighbors
#
# 3. For each undiscovered neighbor:
#    - Assign distance = current distance + 1
#    - Add neighbor to the queue
#
# 4. Repeat until all reachable nodes are processed

# %% [markdown]
# ### Why BFS Is Required
#
# - BFS guarantees:
#   - All nodes at distance *d* are processed
#   - Before any node at distance *d + 1*
#
# - This ensures:
#   - The **first distance assigned is the shortest**

# %% [markdown]
# ### Why DFS Does NOT Work
#
# - DFS explores deep paths first
# - A node may be discovered:
#   - Via a longer path
#   - Before a shorter one is found
#
# - Result:
#   - Incorrect distances ❌

# %% [markdown]
# ### Correctness Intuition
#
# - Distance assignments happen in layers:
#   - Distance 0 → source
#   - Distance 1 → neighbors
#   - Distance 2 → neighbors of neighbors
#
# - By induction:
#   - No shorter path can exist once a node is discovered

# %% [markdown]
# ### Output of the Algorithm
#
# - Returns a dictionary:
#   - Keys: nodes
#   - Values: shortest distance from the source
#
# - Example:
#   ```python
#   {0: 0, 1: 1, 3: 1, 2: 2}

# %% [markdown]
# ```markdown
# ### Key Takeaways
#
# - Dijkstra’s algorithm:
#   - Computes shortest paths from one source
#   - Uses BFS when all edges have equal weight
#
# - Core requirement:
#   - Nodes must be processed in **increasing distance order**
#
# - This version:
#   - Is efficient
#   - Is correct
#   - Prepares us for weighted graphs later

# %% [markdown]
# ## 5.13 Glossary
#
# - **Breadth-First Search (BFS)**
#   An algorithm that starts at a root node and explores all neighboring nodes at the current level before moving on to the next level.
#
# - **Clique**
#   A set of nodes that are completely connected; there is an edge between every pair of nodes in the set.
#
# - **Clustering Coefficient**
#   A measure of the degree to which nodes in a graph tend to cluster together.
#
# - **Clustering**
#   A measure of the “cliquishness” of a graph.
#
# - **Depth-First Search (DFS)**
#   An algorithm that starts at a root node and explores as far as possible along one branch before backtracking.
#
# - **Degree**
#   The number of neighbors a node has.
#
# - **Dijkstra’s Algorithm**
#   An algorithm that solves the single-source shortest path problem by finding the minimum distance from a source node to all other reachable nodes.
#
# - **Generative Model**
#   A model that explains a phenomenon by simulating the process that produces it.
#
# - **Path Length**
#   A measure of the average distance between two nodes in a graph.
#
# - **Queue**
#   A data structure where elements are removed in the same order they are added (First-In, First-Out).
#
# - **Regular Graph**
#   A graph in which every node has the same number of neighbors.
#
# - **Ring Lattice**
#   A type of regular graph where nodes are arranged in a circle and each node is connected to its nearest neighbors.
#
# - **Watts–Strogatz Graph**
#   A graph generation model that produces small-world networks with high clustering and short average path lengths.

# %% [markdown]
# ## 6.1 Introduction
#
# - This chapter analyzes data from an **online social network**.
#
# - A **Watts–Strogatz (WS) graph** is used as an initial model:
#   - WS graphs have **small-world properties** similar to real networks
#   - They exhibit:
#     - Short path lengths
#     - High clustering
#   - However, WS graphs have **low variability in node degree**
#     - Most nodes have a similar number of neighbors
#     - This does not match real social network data
#
# - This limitation motivates the **Barabási–Albert (BA) model**:
#   - BA graphs capture **high variability in node degree**
#   - They model the presence of **highly connected hubs**
#   - BA graphs have:
#     - Short path lengths
#     - But **low clustering**, unlike true small-world networks
#
# - The chapter compares:
#   - WS graphs
#   - BA graphs
#   - Their strengths and limitations as **explanatory models** for small-world networks
#
# - Code for this chapter is provided in:
#   - `chap06.ipynb`
#   - Instructions for using the code are in **Section 1.4**

# %% [markdown]
# ## 6.2 Social Network Data
#
# - Watts–Strogatz (WS) graphs were designed to model **real-world networks**
#   - Examples from the original paper:
#     - Film actors
#     - Power grids
#     - Neural networks (*C. elegans*)
#
# - These networks showed:
#   - **High clustering**
#   - **Short average path lengths**
#   - Key properties of **small-world networks**
#
# - In this section, we analyze a **Facebook social network** dataset
#   - Nodes represent users
#   - Edges represent friendship connections

# %% [markdown]
# ## Facebook Dataset (SNAP)
#
# - Source:
#   - **Stanford Network Analysis Project (SNAP)**
#
# - Dataset details:
#   - 4,039 users (nodes)
#   - 88,234 friendships (edges)
#   - Users labeled from `0` to `4038`
#
# - File format:
#   - One edge per line
#   - Each line contains two user IDs

# %%
def read_graph(filename):
    G = nx.Graph()
    array = np.loadtxt(filename, dtype=int)
    G.add_edges_from(array)
    return G

# %% [markdown]
# ## read_graph Function Explanation
#
# - Purpose:
#   - Read an edge list from a file
#   - Construct a NetworkX graph
#
# - Steps:
#   - Create an empty graph
#   - Load the file into a NumPy array using `loadtxt`
#   - Add edges to the graph using `add_edges_from`
#
# - `dtype=int`:
#   - Ensures node labels are integers

# %%
fb = read_graph('facebook_combined.txt.gz')
n = len(fb)
m = len(fb.edges())
n, m

# %% [markdown]
# ## Dataset Size Verification
#
# - `n`:
#   - Number of nodes in the graph
#   - Result: **4039**
#
# - `m`:
#   - Number of edges (friendships)
#   - Result: **88,234**
#
# - These values match the dataset documentation

# %% [markdown]
# ## Small-World Properties to Measure
#
# To determine whether the Facebook network is a small world, we compute:
#
# - **Clustering coefficient (C)**
#   - Measures how tightly nodes cluster together
#
# - **Average path length (L)**
#   - Measures how many steps it takes to connect two users

# %% [markdown]
# ## Efficient Clustering Estimation
#
# - Exact clustering is slow for large graphs
#   - Time complexity: proportional to \( n \times k^2 \)
#     - `n`: number of nodes
#     - `k`: average number of neighbors
#
# - NetworkX provides an **approximation** method using random sampling

# %%
from networkx.algorithms.approximation import average_clustering
average_clustering(fb, trials=1000)

# %% [markdown]
# ## average_clustering Explanation
#
# - Estimates the **network average clustering coefficient**
# - Uses random sampling for efficiency
# - `trials=1000`:
#   - Number of samples used in the estimate

# %%
def sample_path_lengths(G, nodes=None, trials=1000):
    if nodes is None:
        nodes = list(G)
    else:
        nodes = list(nodes)

    pairs = np.random.choice(nodes, (trials, 2))
    lengths = [nx.shortest_path_length(G, *pair)
               for pair in pairs]
    return lengths

# %% [markdown]
# ## sample_path_lengths Explanation
#
# - Inputs:
#   - `G`: the graph
#   - `nodes`: nodes to sample from
#     - If `None`, sample from the entire graph
#   - `trials`: number of random node pairs
#
# - Process:
#   - Randomly select pairs of nodes
#   - Compute shortest path length for each pair
#
# - Output:
#   - List of sampled path lengths

# %%
def estimate_path_length(G, nodes=None, trials=1000):
    return np.mean(sample_path_lengths(G, nodes, trials))

# %% [markdown]
# ## estimate_path_length Explanation
#
# - Purpose:
#   - Estimate the **average path length (L)**
#
# - Method:
#   - Sample random shortest paths
#   - Return the mean path length

# %%
C = average_clustering(fb)
L = estimate_path_length(fb)
C, L

# %% [markdown]
# ## Results and Interpretation
#
# - Clustering coefficient:
#   - **C ≈ 0.61**
#   - Indicates strong local clustering
#
# - Average path length:
#   - **L ≈ 3.7**
#   - Very short for a network with over 4000 users
#
# - Conclusion:
#   - The Facebook network exhibits **small-world behavior**

# %% [markdown]
# ## Next Step
#
# - Goal:
#   - Construct a **Watts–Strogatz graph**
#   - Match the observed:
#     - Clustering coefficient
#     - Average path length
#
# - This will allow comparison between:
#   - Real social network data
#   - WS model behavior

# %% [markdown]
# ## 6.3 WS Models
#
# - Goal:
#   - Build **Watts–Strogatz (WS) graphs** that resemble the Facebook network
#   - Match two small-world properties:
#     - **High clustering (C)**
#     - **Low average path length (L)**
#
# - We start by matching the **average degree** of the Facebook dataset

# %%
k = int(round(2 * m / n))
k

# %% [markdown]
# ## Average Degree Calculation
#
# - Given:
#   - `n`: number of nodes
#   - `m`: number of edges
#
# - Each edge connects **two nodes**, so:
#   \[
#   k \approx \frac{2m}{n}
#   \]
#
# - Result:
#   - `k = 44`
#   - Each node will have ~44 neighbors in the WS model

# %% [markdown]
# ## WS Graph with p = 0 (Ring Lattice)
#
# - When `p = 0`:
#   - No edges are rewired
#   - The graph is a **regular ring lattice**

# %%
lattice = nx.watts_strogatz_graph(n, k, 0)

# %% [markdown]
# ## Ring Lattice Results
#
# - Clustering coefficient:
#   - **C ≈ 0.70**
#   - Higher than the Facebook dataset (0.61)
#
# - Average path length:
#   - **L ≈ 46**
#   - Much larger than the dataset (3.7)
#
# - Conclusion:
#   - High clustering ✔
#   - Path length too long ✘

# %% [markdown]
# ## WS Graph with p = 1 (Random Graph)
#
# - When `p = 1`:
#   - All edges are randomly rewired
#   - The graph behaves like a **random graph**

# %%
random_graph = nx.watts_strogatz_graph(n, k, 1)

# %% [markdown]
# ## Random Graph Results
#
# - Average path length:
#   - **L ≈ 2.6**
#   - Even shorter than the dataset
#
# - Clustering coefficient:
#   - **C ≈ 0.011**
#   - Extremely low
#
# - Conclusion:
#   - Short paths ✔
#   - Clustering far too low ✘

# %% [markdown]
# ## Choosing an Intermediate p Value
#
# - Idea:
#   - Find a value of `p` that balances:
#     - Short path length
#     - High clustering
#
# - By trial and error:
#   - `p = 0.05` works well

# %%
ws = nx.watts_strogatz_graph(n, k, 0.05, seed=15)

# %% [markdown]
# ## WS Graph with p = 0.05 Results
#
# - Clustering coefficient:
#   - **C ≈ 0.63**
#   - Very close to Facebook (0.61)
#
# - Average path length:
#   - **L ≈ 3.2**
#   - Close to Facebook (3.7)
#
# - This WS graph closely matches the dataset

# %% [markdown]
# ## Final Interpretation
#
# - Ring lattice:
#   - High clustering
#   - Very long paths
#
# - Random graph:
#   - Very short paths
#   - Almost no clustering
#
# - WS graph (p = 0.05):
#   - High clustering
#   - Short paths
#
# - Conclusion:
#   - **Watts–Strogatz graphs successfully model small-world networks**
#   - A small amount of randomness creates realistic social network behavior

# %% [markdown]
# ## 6.4 Degree
#
# - If the WS graph is a good model of the Facebook network, it should match:
#   - The **average degree**
#   - The **variability (spread) of degrees** across nodes
#
# - Looking only at the mean is not enough
#   - We also need to examine the **distribution of degrees**

# %%
def degrees(G):
    return [G.degree(u) for u in G]

# %% [markdown]
# ## Degree Function Explanation
#
# - Input:
#   - `G`: a NetworkX graph
#
# - Output:
#   - A list of node degrees
#   - One degree value per node
#
# - This list allows us to:
#   - Compute statistics (mean, standard deviation)
#   - Build degree distributions

# %% [markdown]
# ## Mean Degree Comparison
#
# - WS model:
#   - Mean degree ≈ **44**
#
# - Facebook dataset:
#   - Mean degree ≈ **43.7**
#
# - Conclusion:
#   - The **average degree matches well**

# %% [markdown]
# ## Standard Deviation Comparison
#
# - WS model:
#   - Standard deviation ≈ **1.47**
#
# - Facebook dataset:
#   - Standard deviation ≈ **52.4**
#
# - Conclusion:
#   - The WS model fails to capture the **degree variability**

# %% [markdown]
# ## Why Mean and Std Are Not Enough
#
# - Two graphs can have:
#   - The same mean degree
#   - Very different structures
#
# - To see the real difference:
#   - We must look at the **entire degree distribution**

# %% [markdown]
# ## Probability Mass Function (PMF)
#
# - We represent degree distributions using a **PMF**
# - PMF = Probability Mass Function
#
# - A PMF maps:
#   - Degree value → fraction of nodes with that degree

# %%
G = nx.Graph()
G.add_edge(1, 0)
G.add_edge(2, 0)
G.add_edge(3, 0)

nx.draw(G)

# %% [markdown]
# ## Example Graph Explanation
#
# - Node `0` is connected to:
#   - Nodes `1`, `2`, and `3`
#
# - Degrees:
#   - Node 0 → degree 3
#   - Nodes 1, 2, 3 → degree 1

# %%
degrees(G)

# %% [markdown]
# ## Degree List Interpretation
#
# - Degree list:

# %% [markdown]
# - Meaning:
# - One node has degree 3
# - Three nodes have degree 1

# %%
from thinkstats2 import Pmf

Pmf(degrees(G))

# %% [markdown]
# ## PMF Interpretation (Example)
#
# - PMF result:

# %% [markdown]
# - Interpretation:
# - 75% of nodes have degree 1
# - 25% of nodes have degree 3

# %% [markdown]
# ## Degree Distribution of Facebook Network

# %%
pmf_fb = Pmf(degrees(fb))
pmf_fb.Mean(), pmf_fb.Std()

# %% [markdown]
# ## Facebook Degree Statistics
#
# - Mean degree ≈ **43.69**
# - Standard deviation ≈ **52.41**
#
# - Interpretation:
#   - Huge variability in number of friends

# %% [markdown]
# ## Degree Distribution of WS Model

# %%
pmf_ws = Pmf(degrees(ws))
pmf_ws.mean(), pmf_ws.std()

# %% [markdown]
# ## WS Degree Statistics
#
# - Mean degree ≈ **44**
# - Standard deviation ≈ **1.47**
#
# - Interpretation:
#   - Most nodes have almost the same number of neighbors

# %% [markdown]
# ## Plotting the Degree Distributions

# %%
thinkplot.Pdf(pmf_fb, label='Facebook')
thinkplot.Pdf(pmf_ws, label='WS graph')

# %% [markdown]
# ## Interpreting Figure 6.1
#
# - WS model:
#   - Degrees tightly clustered around ~44
#   - Very little variation
#
# - Facebook dataset:
#   - Many users with very few friends
#   - A small number of users with **extremely many friends**
#
# - This type of distribution is called:
#   - **Heavy-tailed**

# %% [markdown]
# ## Key Takeaways
#
# - WS graphs:
#   - Match average degree ✔
#   - Fail to match degree variability ✘
#
# - Real social networks:
#   - Have **heavy-tailed degree distributions**
#   - A few hubs, many low-degree nodes
#
# - Motivation:
#   - We need a new model that explains this variability
#   - → Leads to the **Barabási–Albert (BA) model**

# %% [markdown]
# ## 6.5 Heavy-tailed Distributions
#
# - Heavy-tailed distributions are common in:
#   - Social networks
#   - Biology
#   - Economics
#   - Complexity science
#
# - They will appear repeatedly throughout this book

# %% [markdown]
# ## Visualizing Heavy Tails
#
# - Heavy-tailed distributions are hard to interpret on a linear scale
# - A clearer picture appears when we:
#   - Plot the distribution on a **log–log scale**
#
# - This transformation:
#   - Emphasizes the **tail**
#   - Highlights rare but extreme values

# %% [markdown]
# ## Log–Log Scale Intuition
#
# - On a log–log plot:
#   - The x-axis shows `log(k)`
#   - The y-axis shows `log(PMF(k))`
#
# - Large values of `k` become easier to compare
# - Small probabilities become visible

# %%
thinkplot.Pdf(pmf_fb, label='Facebook')
thinkplot.Pdf(pmf_ws, label='WS graph')

thinkplot.Config(xscale='log', yscale='log',
                 xlabel='Degree (k)',
                 ylabel='PMF(k)',
                 legend=True)

# %% [markdown]
# ## Figure 6.2 Interpretation
#
# - Facebook network:
#   - The distribution extends far to the right
#   - Indicates the presence of **hubs**
#   - A small number of nodes have extremely high degree
#
# - WS model:
#   - Distribution drops off quickly
#   - Very few high-degree nodes

# %% [markdown]
# ## Power Law Distributions
#
# - A distribution follows a **power law** if:
#
#   $$
#   \text{PMF}(k) \sim k^{-\alpha}
#   $$
#
# - Where:
#   - `PMF(k)` = fraction of nodes with degree `k`
#   - `α` = positive constant
#   - `~` means “asymptotically proportional to”

# %% [markdown]
# ## Log Transformation of a Power Law
#
# - Taking the logarithm of both sides:
#
#   \[
#   \log(\text{PMF}(k)) \sim -\alpha \log(k)
#   \]
#
# - Result:
#   - A **straight line** on a log–log plot
#   - Slope = **−α**

# %% [markdown]
# ## What Figure 6.2 Suggests
#
# - For large values of `k`:
#   - Facebook degree distribution is approximately linear on log–log axes
#
# - This suggests:
#   - A **power law relationship**
#   - Or at least a heavy-tailed distribution

# %% [markdown]
# ## Important Distinction
#
# - All **power law** distributions are heavy-tailed
# - But:
#   - Not all heavy-tailed distributions are power laws
#
# - Heavy-tailed means:
#   - Extreme values occur more often than expected

# %% [markdown]
# ## Model Mismatch Problem
#
# - WS model:
#   - ✔ High clustering
#   - ✔ Short path lengths
#   - ✘ Narrow degree distribution
#
# - Facebook data:
#   - ✔ High clustering
#   - ✔ Short path lengths
#   - ✔ Heavy-tailed degree distribution

# %% [markdown]
# ## Motivation for a New Model
#
# - WS graphs fail to explain:
#   - Why some nodes become extremely well connected
#
# - This mismatch motivates:
#   - A model that explains **degree variability**
#   - Especially the emergence of hubs

# %% [markdown]
# ## Transition to the Next Section
#
# - This leads to the **Barabási–Albert (BA) model**
# - The BA model explains:
#   - Heavy-tailed degree distributions
#   - Through a process called **preferential attachment**

# %% [markdown]
# ## 6.6 Barabási–Albert (BA) Model
#
# - Introduced by **Barabási and Albert (1999)**
# - Paper: *“Emergence of Scaling in Random Networks”*
#
# - Studied real-world networks such as:
#   - Movie actor collaboration graphs
#   - The World Wide Web
#   - Electrical power grids
#
# - Found that many real networks have:
#   - **Heavy-tailed degree distributions**

# %% [markdown]
# ## Degree Distribution Analysis
#
# - Measure:
#   - Degree `k` of each node
#   - `PMF(k)`: probability a node has degree `k`
#
# - Plot:
#   - `PMF(k)` vs `k` on a **log–log scale**
#
# - Observation:
#   - Straight line for large `k`
#   - Indicates a **heavy-tailed** distribution

# %% [markdown]
# ## Key Features of the BA Model
#
# The BA model differs from the WS model in three key ways:

# %% [markdown]
# ### 1. Growth
#
# - The graph **does not start fixed**
# - Begins with a small initial graph
# - Nodes are added **one at a time**

# %% [markdown]
# ### 2. Preferential Attachment
#
# - New nodes prefer to attach to:
#   - Nodes that already have many connections
#
# - This is known as:
#   - **“Rich get richer”**
#   - Or **preferential attachment**

# %% [markdown]
# ### 3. Power-Law Degree Distribution
#
# - The resulting degree distribution:
#   - Obeys a **power law**
#   - Is heavy-tailed
#
# - Networks with this property are often called:
#   - **Scale-free networks**

# %% [markdown]
# ## Generating a BA Graph with NetworkX

# %%
ba = nx.barabasi_albert_graph(n=4039, k=22)

# %% [markdown]
# ## BA Graph Parameters
#
# - `n = 4039`
#   - Number of nodes (same as Facebook dataset)
#
# - `k = 22`
#   - Number of edges each new node attaches with
#   - Matches average edges per node in the dataset

# %% [markdown]
# ## Degree Statistics Comparison
#
# - Average degree in BA model:
#   - Approximately **44**
#   - Very close to the dataset average
#
# - Degree standard deviation:
#   - Lower than Facebook
#   - Much higher than WS model
#   - A significant improvement over WS

# %% [markdown]
# ## Degree Distribution (Log–Log Plot)
#
# - BA model distribution:
#   - Closely matches Facebook data in the tail
#   - Appears linear on a log–log plot
#
# - Deviations occur:
#   - For small values of `k`
#   - Common limitation of the BA model

# %% [markdown]
# ## Small World Properties of BA Model
#
# - Average path length (L):
#   - Very small
#   - Even smaller than Facebook network
#
# - This confirms:
#   - BA graphs have **short path lengths**

# %% [markdown]
# ## Clustering Limitation
#
# - Clustering coefficient (C):
#   - Much lower than Facebook data
#   - Significantly worse than WS model
#
# - Conclusion:
#   - BA model fails to reproduce **high clustering**

# %% [markdown]
# ## Model Comparison Summary
#
# | Property | Facebook | WS Model | BA Model |
# |--------|----------|---------|---------|
# | Path Length (L) | Short | Short | Very Short |
# | Clustering (C) | High | High | Low |
# | Degree Distribution | Heavy-tailed | Narrow | Heavy-tailed |

# %% [markdown]
# ## Key Takeaway
#
# - WS model:
#   - Explains small-world structure
#   - Fails to explain degree variability
#
# - BA model:
#   - Explains degree variability and hubs
#   - Fails to explain clustering
#
# - No single model captures everything

# %% [markdown]
# ## Fill-in-the-Blank Answer (6.6.1)
#
# The three features that distinguish a BA model from a WS model are:
#
# **growth**, **preferential attachment**, and a degree distribution that obeys a **power law**.

# %% [markdown]
# ## 6.7 Generating BA Graphs
#
# - Previously, BA graphs were generated using NetworkX
# - Now we examine **how the Barabási–Albert model works internally**
# - This version of the algorithm is simplified for readability

# %%
def barabasi_albert_graph(n, k):

    G = nx.empty_graph(k)
    targets = list(range(k))
    repeated_nodes = []

    for source in range(k, n):
        G.add_edges_from(zip([source]*k, targets))

        repeated_nodes.extend(targets)
        repeated_nodes.extend([source] * k)

        targets = _random_subset(repeated_nodes, k)

    return G

# %% [markdown]
# ## Function Parameters
#
# - `n`
#   - Total number of nodes in the final graph
#
# - `k`
#   - Number of edges each new node creates
#   - Becomes the **average degree / 2**

# %% [markdown]
# ## Initial Graph Setup
#
# - Start with:
#   - `k` nodes
#   - No edges
#
# - This ensures:
#   - New nodes always have existing nodes to connect to

# %% [markdown]
# ## Key Data Structures
#
# ### `targets`
# - List of nodes the next new node will connect to
# - Initially:
#   - The original `k` nodes
# - Later:
#   - A random subset chosen using preferential attachment
#
# ### `repeated_nodes`
# - A list where:
#   - Each node appears once per connected edge
# - Nodes with higher degree appear more often
# - Enables **preferential attachment**

# %% [markdown]
# ## Main Loop Explanation
#
# - Loop over new nodes from `k` to `n-1`
#
# For each new node (`source`):
#
# 1. Add edges to all nodes in `targets`
# 2. Update `repeated_nodes`:
#    - Add each target once
#    - Add the new node `k` times
# 3. Select new targets using `_random_subset`

# %% [markdown]
# ## Why Preferential Attachment Works
#
# - New targets are chosen from `repeated_nodes`
# - Nodes with higher degree:
#   - Appear more often
#   - Have higher probability of being selected
#
# - Result:
#   - **“Rich get richer”** behavior

# %%
def _random_subset(repeated_nodes, k):
    targets = set()
    while len(targets) < k:
        x = random.choice(repeated_nodes)
        targets.add(x)
    return targets

# %% [markdown]
# ## _random_subset Explanation
#
# - Randomly selects `k` **unique nodes**
# - Uses a `set` to:
#   - Automatically discard duplicates
# - Sampling from `repeated_nodes` ensures:
#   - Selection probability is proportional to node degree

# %% [markdown]
# ## Summary of BA Graph Generation
#
# - Nodes are added one at a time
# - Each new node connects to `k` existing nodes
# - Connection probability depends on existing degree
# - Resulting graph:
#   - Has a **heavy-tailed (power-law) degree distribution**
#   - Models hub formation in real networks

# %% [markdown]
# ## 6.8 Cumulative Distributions
#
# - Degree distributions are often shown using **PMFs on log-log scales**
# - This is common in power-law analysis, but it has drawbacks:
#   - PMFs can be noisy
#   - Tails are hard to interpret visually
#
# - A better alternative is the **Cumulative Distribution Function (CDF)**

# %% [markdown]
# ## Cumulative Distribution Function (CDF)
#
# - A CDF maps a value `x` to:
#   - The fraction of values **less than or equal to x**
#
# - For degree distributions:
#   - CDF(k) = fraction of nodes with degree ≤ k

# %%
def cumulative_prob(pmf, x):
    ps = [pmf[value] for value in pmf if value <= x]
    return np.sum(ps)

# %% [markdown]
# ## cumulative_prob Explanation
#
# - Inputs:
#   - `pmf`: probability mass function
#   - `x`: value to evaluate
#
# - Process:
#   - Sum probabilities for all values ≤ x
#
# - Output:
#   - Cumulative probability up to x

# %%
cumulative_prob(pmf_fb, 25)

# %% [markdown]
# ## Interpreting the Result
#
# - Result ≈ 0.506
# - Meaning:
#   - About **50% of users have 25 or fewer friends**
# - Therefore:
#   - The **median degree ≈ 25**

# %% [markdown]
# ## Why CDFs Are Better Than PMFs
#
# - CDFs are:
#   - Smoother
#   - Less noisy
#   - Easier to interpret
#
# - Once familiar, CDFs give a clearer picture of:
#   - Distribution shape
#   - Tail behavior

# %%
from thinkstats2 import Cdf
cdf_fb = Cdf(degrees(fb), label='Facebook')

# %% [markdown]
# ## Computing the CDF
#
# - `Cdf` takes a list of values (degrees)
# - Produces a cumulative distribution object
# - Labels are useful for plotting comparisons

# %%
thinkplot.Cdf(cdf_fb)

# %% [markdown]
# ## Interpreting Figure 6.4 (CDF Plot)
#
# - Shows degree CDF for:
#   - Facebook dataset
#   - WS model
#   - BA model
#
# - X-axis:
#   - Logarithmic scale
#
# - Observations:
#   - WS model differs significantly from data
#   - BA model is closer, but still imperfect

# %% [markdown]
# ## Complementary CDF (CCDF)
#
# - Defined as:
#   - CCDF(x) = P(X > x)
#
# - Useful because:
#   - If PMF follows a power law
#   - CCDF also follows a power law

# %% [markdown]
# ## CCDF and Power Laws
#
# - For a power-law distribution:
#   - CCDF(x) ∝ x^(−α)
#
# - On a log-log plot:
#   - CCDF appears as a straight line
#   - Slope = −α

# %% [markdown]
# ## Interpreting Figure 6.5 (CCDF Plot)
#
# - CCDF plotted on a log-log scale
# - Comparison:
#   - Facebook data
#   - WS model
#   - BA model
#
# - Observations:
#   - WS model does **not** match the tail
#   - BA model matches the tail reasonably well
#     - Especially for degree > 20

# %% [markdown]
# ## Key Takeaways
#
# - CDFs and CCDFs are better tools than PMFs for:
#   - Heavy-tailed distributions
#   - Power-law analysis
#
# - Results:
#   - WS model fails to match degree distribution
#   - BA model captures the tail behavior well

# %% [markdown]
# ## 6.9 Explanatory Models
#
# - We began studying networks with **Milgram’s Small World Experiment**
# - Key observation:
#   - Social networks have **surprisingly short path lengths**
#   - Often described as *“six degrees of separation”*
#
# - When we observe something surprising, a natural question is:
#   - **Why does this happen?**

# %% [markdown]
# ## What Is an Explanatory Model?
#
# - One way to answer “why” questions is with an **explanatory model**
# - Figure 6.6 illustrates the logical structure of such a model
#
# - An explanatory model:
#   - Does not claim to be a perfect copy of reality
#   - Attempts to capture **essential features** of a system

# %% [markdown]
# ## Logical Structure of an Explanatory Model
#
# 1. In a real system **S**, we observe a phenomenon **P** that needs explanation
#
# 2. We construct a model **M** that is analogous to **S**
#    - Elements of **M** correspond to elements of **S**
#
# 3. Using simulation or mathematical analysis:
#    - The model **M** exhibits a behavior **Q**
#    - Behavior **Q** is analogous to **P**
#
# 4. We conclude:
#    - **S exhibits P because M is similar to S and M exhibits Q**

# %% [markdown]
# ## Argument by Analogy
#
# - At its core, an explanatory model is an **argument by analogy**
#
# - Logic:
#   - If two systems are similar in some ways
#   - They may be similar in other ways as well
#
# - This kind of reasoning can be:
#   - Intuitive
#   - Insightful
#   - Persuasive

# %% [markdown]
# ## Important Limitation
#
# - Explanatory models are **not mathematical proofs**
# - They do not guarantee that the explanation is *true*
# - They only show that the explanation is *plausible*

# %% [markdown]
# ## Abstraction in Models
#
# - All models:
#   - Leave out details
#   - “Abstract away” features considered unimportant
#
# - For any real system:
#   - Many different models are possible
#   - Each model emphasizes different features

# %% [markdown]
# ## Competing Explanations
#
# - Different models may:
#   - Explain the same phenomenon
#   - Emphasize different mechanisms
#
# - When multiple models explain the same observation:
#   - Which one is correct?
#   - Or are multiple explanations valid?

# %% [markdown]
# ## Small World Phenomenon as an Example
#
# - The **small world effect** has multiple explanations
# - Two major models:
#   - Watts–Strogatz (WS) model
#   - Barabási–Albert (BA) model

# %% [markdown]
# ## WS Model Explanation
#
# - The WS model suggests networks are small because:
#   - Nodes form **tightly clustered groups**
#   - A few **weak ties** connect different clusters
#
# - Result:
#   - High clustering
#   - Short average path lengths

# %% [markdown]
# ## BA Model Explanation
#
# - The BA model suggests networks are small because:
#   - Some nodes become **high-degree hubs**
#   - Hubs grow through **preferential attachment**
#
# - Result:
#   - Heavy-tailed degree distributions
#   - Efficient global connectivity

# %% [markdown]
# ## Final Insight
#
# - In young scientific fields:
#   - The problem is often **not too few explanations**
#   - But **too many plausible explanations**
#
# - Explanatory models help us think clearly
# - But they must be:
#   - Compared
#   - Tested
#   - Interpreted with care
